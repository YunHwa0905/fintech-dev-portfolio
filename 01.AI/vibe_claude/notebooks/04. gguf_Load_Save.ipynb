# %%
try:
    import google.colab
    inColab = True
except ImportError:
    inColab = False
if inColab == True:
    from google.colab import drive
    drive.mount("/content/gdrive")

# %%
import os
from huggingface_hub import snapshot_download
from huggingface_hub import HfApi

# %%
if inColab == True:
    target_dir = "C:\Users\SMT21\Desktop\gitMaster\fintech-dev-portfolio\01.AI\vibe_claude\gguf"
    os.makedirs(target_dir, exist_ok=True)  # 폴더 없으면 생성
    # %cd $target_dir

# %%
### GGUF 파일 허깅페이스 내 업로드 위해 로그인 필요
from huggingface_hub import notebook_login
notebook_login()

# %%
cd C:\Users\SMT21\Desktop\gitMaster\fintech-dev-portfolio\01.AI\vibe_claude\gguf
# Out:
# C:\Users\SMT21\Desktop\gitMaster\fintech-dev-portfolio\01.AI\vibe_claude\gguf

# %%
# %pwd
# Out:
# 'C:\\Users\\SMT21\\Desktop\\gitMaster\\fintech-dev-portfolio\\01.AI\\vibe_claude\\gguf'

# %%
# 현재 폴더 기준 gdownPath 폴더가 생성되고 허깅페이스의 model_id 이름의 모델이 다운로드 됨
# gdownPath = "gemma2b_pharos"
gdownPath = "gemma-3-4b-it_2026_04_23_16"
# 불러올 허깅페이스모델 (model_id 변수에 할당)
# model_id="hyokwan/familidata_elysium_4b"
# model_id = "hyokwan/pharos_2b"
model_id="yunhwa/law_alpaca"
# 현재 폴더 기준 폴더 생성
# 구글드라이브에 이미 있으면 두번 실행할 필요는 없다!
snapshot_download(repo_id=model_id, local_dir=gdownPath,
                          local_dir_use_symlinks=False, revision="main")
# Out:
# c:\Users\SMT21\Desktop\gitMaster\fintech-dev-portfolio\01.AI\vibe_claude\.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ...
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# 'C:\\Users\\SMT21\\Desktop\\gitMaster\\fintech-dev-portfolio\\01.AI\\vibe_claude\\gguf\\gemma-3-4b-it_2026_04_23_16'

# %%
# 2025년 12월15일 기준 requirements.txt 내 아래 패키지 (mistral_common==1.8.5) 존재하지 않아 추가 설치
# no module named mistral_common 에러시 아래 코드 실행 후 패키지 설치
# !pip install mistral_common==1.8.5
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\WORKPC\.torchcore\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\WORKPC\.torchcore\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\WORKPC\.torchcore\Lib\site-packages)

# %%
# !git clone https://github.com/ggerganov/llama.cpp
# Out:
# Cloning into 'llama.cpp'...
# Updating files:  38% (1016/2617)
# Updating files:  39% (1021/2617)
# Updating files:  40% (1047/2617)
# Updating files:  41% (1073/2617)
# Updating files:  42% (1100/2617)
# Updating files:  43% (1126/2617)
# Updating files:  44% (1152/2617)
# Updating files:  45% (1178/2617)
# Updating files:  46% (1204/2617)
# Updating files:  47% (1230/2617)
# Updating files:  48% (1257/2617)
# Updating files:  49% (1283/2617)
# Updating files:  50% (1309/2617)
# Updating files:  51% (1335/2617)
# Updating files:  52% (1361/2617)
# Updating files:  53% (1388/2617)
# Updating files:  54% (1414/2617)
# Updating files:  55% (1440/2617)
# Updating files:  56% (1466/2617)
# Updating files:  57% (1492/2617)
# Updating files:  58% (1518/2617)
# Updating files:  59% (1545/2617)
# Updating files:  60% (1571/2617)
# Updating files:  61% (1597/2617)
# Updating files:  62% (1623/2617)
# Updating files:  63% (1649/2617)
# Updating files:  64% (1675/2617)
# ...

# %%
# !pip install -r llama.cpp/requirements.txt

# %%
# 현재 위치에서 폴더 및 파일목록 확인 명령어
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: D883-A34C
#
#  C:\Users\WORKPC\Desktop\ggufs 디렉터리
#
# 2026-04-10  오후 02:38    <DIR>          .
# 2026-04-10  오후 02:29    <DIR>          ..
# 2026-04-10  오전 11:07    <DIR>          .ipynb_checkpoints
# 2026-04-10  오후 02:38    <DIR>          kopo_gemma3_4b_20260410
# 2026-04-10  오후 01:56    <DIR>          llama.cpp
#                0개 파일                   0 바이트
#                5개 디렉터리  232,227,344,384 바이트 남음

# %%
####### ★★★ 수정 포인트★★★ ############
# !python llama.cpp/convert_hf_to_gguf.py [파인튜닝모델 다운로드 폴더위치] --outfile [GGUF 파일명].gguf --outtype {f32, f16, bf16, q8_0, auto}
# !python llama.cpp/convert_hf_to_gguf.py kopo_gemma3_4b --outfile kopo_2026_gemma4b.gguf --outtype q8_0
# !python llama.cpp/convert_hf_to_gguf.py gemma-3-4b-it_2026_04_23_16 --outfile law_20260410_gemma4b.gguf --outtype f16
# Out:
# INFO:hf-to-gguf:Loading model: gemma-3-4b-it_2026_04_23_16
# INFO:hf-to-gguf:Model architecture: Gemma3ForConditionalGeneration
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00001-of-00002.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00002-of-00002.safetensors'
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:token_embd.weight,                 torch.bfloat16 --> F16, shape = {2560, 262208}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,            torch.bfloat16 --> F32, shape = {2560}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,             torch.bfloat16 --> F16, shape = {10240, 2560}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,             torch.bfloat16 --> F16, shape = {2560, 10240}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,               torch.bfloat16 --> F16, shape = {2560, 10240}
# ...

# %%
api = HfApi()

####### ★★★ 수정 포인트★★★ ############
# gguf 파일 경로
file_path = r"C:\Users\SMT21\Desktop\gitMaster\fintech-dev-portfolio\01.AI\vibe_claude\gguf\law_20260410_gemma4b.gguf"

# Hugging Face 저장소 이름
repo_name = "yunhwa/ai_questions_gguf"

# 파일 업로드
api.upload_file(
    path_or_fileobj=file_path,
    path_in_repo="law_20260410_gemma4b.gguf",  # 저장소 내 파일 경로
    repo_id=repo_name,
    repo_type="model",  # 모델 저장소에 업로드
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/yunhwa/ai_questions_gguf/commit/c90efe4b9917bea13ee2960784abd5162a82bc18', commit_message='Upload law_20260410_gemma4b.gguf with huggingface_hub', commit_description='', oid='c90efe4b9917bea13ee2960784abd5162a82bc18', pr_url=None, repo_url=RepoUrl('https://huggingface.co/yunhwa/ai_questions_gguf', endpoint='https://huggingface.co', repo_type='model', repo_id='yunhwa/ai_questions_gguf'), pr_revision=None, pr_num=None)
